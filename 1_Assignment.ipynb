# %% [markdown]
# # Convert integer to string

# %%
num = 5
num_as_string = str(num)

print(num_as_string)
print(type(num_as_string))
# Out:
# 5
# <class 'str'>

# %% [markdown]
# # Difference between = and ==

# %%
a = 5

if a == 5:
    print("Equal")
# Out:
# Equal

# %% [markdown]
# # Modulus

# %%
print(10 % 3)
# Out:
# 1

# %%
x = 10

if x % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %% [markdown]
# # Type casting

# %%
a = 10

print(str(a))
print(int(a))
print(float(a))
# Out:
# 10
# 10
# 10.0

# %% [markdown]
# # What is 3 * "Hello"?

# %%
print(3 * "Hello")
# Out:
# HelloHelloHello

# %% [markdown]
# # String concatenation

# %%
first_name = "John"
last_name = "Doe"

full_name = first_name + "John " + "Doe"
last_name

print(full_name)
# Out:
# JohnJohn Doe
