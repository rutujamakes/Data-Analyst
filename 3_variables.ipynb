# %%
In [1]:
# Out:
#   Cell In[1], line 1
#     In [1]:
#            ^
# SyntaxError: invalid syntax

# %%
a = 5

# %%
a
# Out:
# 5

# %%
5 = 10
# Out:
#   Cell In[4], line 1
#     5 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a5 = 10

# %%
a5
# Out:
# 10

# %%
a_5 = 20

# %%
a_5
# Out:
# 20

# %%
@ = 50
# Out:
#   Cell In[9], line 1
#     @ = 50
#       ^
# SyntaxError: invalid syntax

# %%
$ = 'Hello'
# Out:
#   Cell In[10], line 1
#     $ = 'Hello'
#     ^
# SyntaxError: invalid syntax

# %%
type(5)
# Out:
# int

# %%
type = 50

# %%
type
# Out:
# 50

# %%
del type

# %%
type(5)
# Out:
# int

# %%
len('Hello')
# Out:
# 5

# %%
len = 50

# %%
len
# Out:
# 50

# %%
a = 5

# %%
b = 10

# %%
c = a + b #5 + 10

# %%
c
# Out:
# 15

# %%
x,y,z = 10,20,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
o = 1,2,3,4,5,6

# %%
o
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
name = 'Rutuja'
last_name = 'Ingale'

# %%
name + last_name
# Out:
# 'RutujaIngale'

# %%
name + ' ' + last_name
# Out:
# 'Rutuja Ingale'

# %%
'My name is' + name
# Out:
# 'My name isRutuja'

# %%
' My name is ' + name
# Out:
# ' My name is Rutuja'

# %%
'My first name is ' + name + 'last name is ' + last_name
# Out:
# 'My first name is Rutujalast name is Ingale'

# %%
a
# Out:
# 5

# %%
a + 5
# Out:
# 10

# %%
a
# Out:
# 5

# %%
a = a + 5

# %%
a
# Out:
# 10

# %%
b = 10

# %%
b = b - 5

# %%
b
# Out:
# 5

# %%
c = 20

# %%
c += 5 # c = c + 5

# %%
c
# Out:
# 25

# %%
# type casting

# %%
num = 10

# %%
type(10)
# Out:
# int

# %%
num2 = '10'

# %%
type(num2)
# Out:
# str

# %%
int(num2)
# Out:
# 10

# %%
num2 = int(num2)

# %%
type(num2)
# Out:
# int

# %%
int('123')
# Out:
# 123

# %%
float(10)
# Out:
# 10.0

# %%
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
str(121)
# Out:
# '121'

# %%
# operations

# %%
name
# Out:
# 'Rutuja'

# %%
print('My name is ' + name)
# Out:
# My name is Rutuja

# %%
print(' My age is ', + 22)
# Out:
#  My age is  22

# %%
age = 22

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is Rutuja and my age is 22

# %%
name = 'Om'

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is Om and my age is 22
