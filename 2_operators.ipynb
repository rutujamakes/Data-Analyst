# %%
10 + 5
# Out:
# 15

# %%
10 - 5
# Out:
# 5

# %%
10 * 5
# Out:
# 50

# %%
10 / 5
# Out:
# 2.0

# %%
10 % 2
# Out:
# 0

# %%
10 % 3
# Out:
# 1

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 % 5
# Out:
# 0

# %%
10 % 4
# Out:
# 2

# %%
10 / 4
# Out:
# 2.5

# %%
10 // 4
# Out:
# 2

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
2 ** 3
# Out:
# 8

# %%
5 ** 2
# Out:
# 25

# %%
10 ** 2
# Out:
# 100

# %%
'Hello' * 3
# Out:
# 'HelloHelloHello'

# %%
# Compare two dataset

# %%
10 > 5
# Out:
# True

# %%
5 < 10
# Out:
# True

# %%
5 > 10
# Out:
# False

# %%
5 > 5
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
10 == 5
# Out:
# False

# %%
'hello' == 'hello'
# Out:
# True

# %%
'Hello' =='hello'
# Out:
# False

# %%
5 != 5
# Out:
# False

# %%
'exit' != 'exit'
# Out:
# False

# %%
5 < 5
# Out:
# False

# %%
5 > 5
# Out:
# False

# %%
5 >= 5
# Out:
# True

# %%
5 <= 5
# Out:
# True

# %%
10 <= 5
# Out:
# False

# %%
# 5 == 5 ------ ?

# %%
# Logical operators

# %%
True & True
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
True - False
# Out:
# 1

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
10 < 20 & 10 > 5
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
10 > 5
# Out:
# True

# %%
True & True
# Out:
# True

# %%
10 < 20 and 10 > 5 # True and True
# Out:
# True

# %%
5 > 0 and 10 > 20 # True and False
# Out:
# False

# %%
5 + 100
# Out:
# 105

# %%
10 + 'Hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 10 + 'Hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'Hello' + 'Python'
# Out:
# 'HelloPython'

# %%
10 + 0.5
# Out:
# 10.5

# %%
# Concatination Operation ---> Same data type

# %%
10 + True
# Out:
# 11
