# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
5.5
# Out:
# 5.5

# %%
type(5.5)
# Out:
# float

# %%
10 + 5j
# Out:
# (10+5j)

# %%
'Hello'
# Out:
# 'Hello'

# %%
'python'
# Out:
# 'python'

# %%
"""Today we have started Python.
Now we are learning data types in python.
We have learned 4 data types till now."""
# Out:
# 'Today we have started Python.\nNow we are learning data types in python.\nWe have learned 4 data types till now.'

# %%
print("""Today we have started Python.
Now we are learning data types in python.
We have learned 4 data types till now.""")
# Out:
# Today we have started Python.
# Now we are learning data types in python.
# We have learned 4 data types till now.

# %%
type('Hello')
# Out:
# str

# %%
5 > 2
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool
