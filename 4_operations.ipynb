# %%
# User input

# %%
name = input('Write your good name')
print(f'Your Good name is {name}')
# Out:
# Write your good name Rutuja
# Your Good name is Rutuja

# %%
name = input('Write your good name')
last_name = input('Enter your last name')
print(f'Your first name is {name} and last name is{last_name}')
# Out:
# Write your good name Rutuja
# Enter your last name Ingale
# Your first name is Rutuja and last name isIngale

# %%
name
# Out:
# 'Rutuja'

# %%
type(name)
# Out:
# str

# %%
age = input('Enter your age')
print(f'Your age is {age}')
# Out:
# Enter your age 22
# Your age is 22

# %%
age
# Out:
# '22'

# %%
type(age)
# Out:
# str

# %%
age = int(input('Fill  your age'))
print(f'Your age is {age}')
# Out:
# Fill  your age 22
# Your age is 22

# %%
age
# Out:
# 22

# %%
type(age)
# Out:
# int

# %%
marks = float(input('Enter your grade'))
print(f'You have {marks} grade')
# Out:
# Enter your grade 9.5
# You have 9.5 grade

# %%
type(marks)
# Out:
# float

# %%
marks = input('Marks')
# Out:
# Marks 7.5

# %%
marks
# Out:
# '7.5'

# %%
print('You have', age, 'grade')
# Out:
# You have 22 grade

# %%
a = 5
b = 3
c = 1

# %%
print(f'Value for a is {a} and b {b} and c {c} and addition of a and b is {a+b}')
# Out:
# Value for a is 5 and b 3 and c 1 and addition of a and b is 8
